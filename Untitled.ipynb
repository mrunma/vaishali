# %%
print("hello world")
# Out:
# hello world

# %%
print("vaishali")
# Out:
# vaishali

# %%
print("data science")
# Out:
# data science

# %%
x=10
y=5
print(x+y)
# Out:
# 15

# %%
10+5
# Out:
# 15
